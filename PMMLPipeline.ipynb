# %%
#Notebook to create ML pipeline for Java Plugin
from sklearn2pmml import PMMLPipeline, sklearn2pmml
import pandas as pd
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn import model_selection, preprocessing, neural_network, metrics, linear_model, svm
import os
from sklearn2pmml.feature_extraction.text import Splitter
import string
import random
import numpy as np
import nltk
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
filename = "Chatbot_Train.csv"
num_inputs = 5
data = pd.read_csv(filename)
data
# Out:
#                                    input_1  \
# 0                     What is my altitude?
# 1              What is the oxygen content?
# 2                    How fast is the wind?
# 3             What is the atmosphere like?
# 4      What is the gravity on this planet?
# 5                                 Humidity
# 6                           Magnetic field
# 7                                 Pressure
# 8                                Radiation
# 9            What is the year length here?
# 10                             Where am I?
# 11                               Who am I?
# 12                           What is this?
# 13                  What should I do next?
# 14         What does Saige do for her job?
# 15                            How are you?
# 16                                 See you
# 17        What is the tilt on this planet?
# 18                 What's the tide levels?
# 19         What's the temp on this planet?
# 20                               tektounic
# 21                                     day
# 22                                  Radius
# 23            What are the rays like here?
# 24           I want to make an observation
# 25                      What is your name?
# 26                  What are your hobbies?
# 27                    Where's the chemist?
# 28                      Who can I talk to?
# 29  Where can I find the exonaut explorer?
# 30      Where can I find the xenobotanist?
# 31    Where can I find the astrozooligist?
# 32             Where can I find the robot?
# 33          Where can I find Eric Mattson?
# 34        Where can I find the prospector?
# 35          Where can I find the surveyor?
# 36       What does kobey do for their job?
# 37        What does nate do for their job?
# 38      What does galvin do for their job?
# 39      What does theron do for their job?
# 40            Can you direct me to {Nate}?
#
#                                             input_2  \
# 0                                 How high up am I?
# 1                                Can I breath here?
# 2                         What is the airflow like?
# 3                               Atmosphere contents
# 4                                           Gravity
# 5                        What is the humidity here?
# 6        What is the magnetic force on this planet?
# 7               What is the pressure on the planet?
# 8   What is the amount of radiation on this planet?
# 9                How long is a year on this planet?
# 10                             What planet am I on?
# 11                                 What is my name?
# 12                            What am I looking at?
# 13                               Where do I go now?
# 14                          Where can I find Saige?
# 15                                            Hello
# 16                                              bye
# 17                                             Tilt
# 18              High how are the ocean levels here?
# 19                                 Temperature here
# 20                  Seismic activity on this planet
# 21  How long does it take for the planet to rotate?
# 22           What is the mean radius of the planet?
# 23   How much localized cosmic rays are there here?
# 24                                          observe
# 25                                     Who are you?
# 26                          What do you like to do?
# 27                                          Chemist
# 28                       What npcs are on this map?
# 29                                 Exonaut explorer
# 30                                     xenobotanist
# 31                                   astrozooligist
# 32                                            robot
# 33                                     Eric Mattson
# 34                                       prospector
# 35                                         surveyor
# 36                          Where can I find kobey?
# 37                           Where can I find nate?
# 38                         Where can I find galvin?
# 39                         Where can I find theron?
# 40                How to I get back to the {start}?
#
#                                               input_3  \
# 0                                       Altitude here
# 1                                              Oxygen
# 2        What is the speed of the air on this planet?
# 3                               What is in the water?
# 4                  What is the force pulling me down?
# 5                How moist is the air on this planet?
# 6   What is the force that keeps the planet together?
# 7          What is the force exerted on my body here?
# 8            How much energy do I get on this planet?
# 9                  How old would I be on this planet?
# 10                    What's the name of my location?
# 11                                    Do you know me?
# 12                      Tell me something about this.
# 13                                         I am lost.
# 14                                      Who is Saige?
# 15                                         What's up?
# 16                                            goodbye
# 17                  How far off are we from the axis?
# 18            What are the tides like on this planet?
# 19                                            Celcius
# 20             What is the tectonic plates like here?
# 21         What is the length of days on this planet?
# 22                            How big is this planet?
# 23                                        cosmic rays
# 24                     How to I write an observation?
# 25                                             Friend
# 26                  Tell me something about yourself?
# 27                                Who is the chemist?
# 28                           Where can I find people?
# 29                       Who is the exonaut explorer?
# 30                           Who is the xenobotanist?
# 31                         Who is the astrozooligist?
# 32                                 Where's the robot?
# 33                               Who is Eric Mattson?
# 34                             Who is the prospector?
# 35                               Who is the surveyor?
# 36                                      Who is kobey?
# 37                                       Who is nate?
# 38                                     Who is galvin?
# 39                                     Who is theron?
# 40                   Can I get directions to {pool1}?
#
#                                            input_4  \
# 0                                           Height
# 1                     Is there air on this planet?
# 2                                             Wind
# 3                                       Atmosphere
# 4                                              NaN
# 5            What is the water content in the air?
# 6                                              NaN
# 7   How much is being pushed on me on this planet?
# 8                             Can I get sick here?
# 9                                      Year length
# 10                                     Planet name
# 11                                          Player
# 12                         Do you know about this?
# 13                                 Quest progress.
# 14                                  Engineer Saige
# 15                                              Hi
# 16                                     I got to go
# 17                                      Axial tilt
# 18                                     ocean level
# 19                                          Kelvin
# 20                                        tectonic
# 21                        What are days like here?
# 22              How many miles is the radius here?
# 23                                             NaN
# 24                                             NaN
# 25                                        AI agent
# 26                                        passions
# 27                   Where can I find the Chemist?
# 28                      Who do I need to speak to?
# 29                   Where's the exonaut explorer?
# 30                       Where's the xenobotanist?
# 31                     Where's the astrozooligist?
# 32                         What does the robot do?
# 33                           Where's Eric Mattson?
# 34                         Where's the prospector?
# 35                           Where's the surveyor?
# 36                                 Scientist kobey
# 37                                 researcher nate
# 38                                geologist galvin
# 39                    astronomer theron carmichael
# 40                                             NaN
#
#                                               input_5           topic
# 0                                                 Alt        altitude
# 1                                                 Air          oxygen
# 2                                             Airflow         airflow
# 3                            What is in the air here?      atmosphere
# 4                  How fast fo I fall on this planet?         gravity
# 5                               How humid is it here?        humidity
# 6                                                 NaN  magnetic field
# 7                           Would I get crushed here?        pressure
# 8                                         Wave energy       radiation
# 9   How long does it take for this planet to orbit...            year
# 10                                           Location          planet
# 11                                               Name          player
# 12                                                NaN         caption
# 13                                       What's next.           quest
# 14                                     Where's Saige?            npcs
# 15                                                Hey        greeting
# 16                                Nice talking to you         goodbye
# 17                                               Axis            tilt
# 18                                               tide            tide
# 19                                         Fahrenheit     temperature
# 20            What is the seismic activity like here?        tectonic
# 21                                           Rotation             day
# 22                                                NaN          radius
# 23                                                NaN             ray
# 24                                                NaN         observe
# 25                          Why are you following me?           agent
# 26                                              hobby           hobby
# 27            What does the chemist do for their job?            npcs
# 28                              Who am I looking for?            npcs
# 29  What does the exoplanet explorer do for their ...            npcs
# 30       What does the xenobotanist do for their job?            npcs
# 31     What does the astrozooligist do for their job?            npcs
# 32                                                NaN            npcs
# 33           What does Eric Mattson do for their job?            npcs
# 34         What does the prospector do for their job?            npcs
# 35           What does the surveyor do for their job?            npcs
# 36                                     Where's kobey?            npcs
# 37                                      Where's nate?            npcs
# 38                                    Where's galvin?            npcs
# 39                                    Where's theron?            npcs
# 40                                                NaN        guidance

# %%
#method to get appropriate part of speech (need to run tests to check if works properly)
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, articles):
        return [self.wnl.lemmatize(t, get_wordnet_pos(t)) for t in word_tokenize(articles)]

# %%
X = []
y = []
topics = []

# Loop csv append topic
for i, j in data.iterrows():
    class_value = data.iloc[i]["topic"]
    if not pd.isna(class_value):
        for k in range(num_inputs):
            col_value = k+1
            row_input = data.iloc[i]["input_"+str(col_value)]
            if not pd.isna(row_input):
                X.append(row_input)
                y.append(class_value)
    # Add class if topic not present in list
    if class_value not in topics:
        topics.append(class_value)

print(topics)
print(X)
print(y)
# Out:
# ['altitude', 'oxygen', 'airflow', 'atmosphere', 'gravity', 'humidity', 'magnetic field', 'pressure', 'radiation', 'year', 'planet', 'player', 'caption', 'quest', 'npcs', 'greeting', 'goodbye', 'tilt', 'tide', 'temperature', 'tectonic', 'day', 'radius', 'ray', 'observe', 'agent', 'hobby', 'guidance']
# ['What is my altitude?', 'How high up am I?', 'Altitude here', 'Height', 'Alt', 'What is the oxygen content?', 'Can I breath here?', 'Oxygen', 'Is there air on this planet?', 'Air', 'How fast is the wind?', 'What is the airflow like?', 'What is the speed of the air on this planet?', 'Wind', 'Airflow', 'What is the atmosphere like?', 'Atmosphere contents', 'What is in the water?', 'Atmosphere', 'What is in the air here?', 'What is the gravity on this planet?', 'Gravity', 'What is the force pulling me down?', 'How fast fo I fall on this planet?', 'Humidity', 'What is the humidity here?', 'How moist is the air on this planet?', 'What is the water content in the air?', 'How humid is it here?', 'Magnetic field', 'What is the magnetic force on this planet?', 'What is the force that keeps the planet together?', 'Pressure', 'What is the pressure on the planet?', 'What is the force exerted on my body here?', 'How much is being pushed on me on this planet?', 'Would I get crushed here?', 'Radiation', 'What is the amount of radiation on this planet?', 'How much energy do I get on this planet?', 'Can I get sick here?', 'Wave energy', 'What is the year length here?', 'How long is a year on this planet?', 'How old would I be on this planet?', 'Year length', 'How long does it take for this planet to orbit their sun?', 'Where am I?', 'What planet am I on?', "What's the name of my location?", ' Planet name', 'Location', 'Who am I?', 'What is my name?', 'Do you know me?', 'Player', 'Name', 'What is this?', 'What am I looking at?', 'Tell me something about this.', 'Do you know about this?', 'What should I do next?', 'Where do I go now?', 'I am lost.', 'Quest progress.', "What's next.", 'What does Saige do for her job?', 'Where can I find Saige?', 'Who is Saige?', 'Engineer Saige', "Where's Saige?", 'How are you?', 'Hello', "What's up?", 'Hi', 'Hey', 'See you', 'bye', 'goodbye', 'I got to go', 'Nice talking to you', 'What is the tilt on this planet?', 'Tilt', 'How far off are we from the axis?', 'Axial tilt', 'Axis', "What's the tide levels?", 'High how are the ocean levels here?', 'What are the tides like on this planet?', 'ocean level', 'tide', "What's the temp on this planet?", 'Temperature here', 'Celcius', 'Kelvin', 'Fahrenheit', 'tektounic', 'Seismic activity on this planet', 'What is the tectonic plates like here?', 'tectonic', 'What is the seismic activity like here?', 'day', 'How long does it take for the planet to rotate?', 'What is the length of days on this planet?', 'What are days like here?', 'Rotation', 'Radius', 'What is the mean radius of the planet?', 'How big is this planet?', 'How many miles is the radius here?', 'What are the rays like here?', 'How much localized cosmic rays are there here?', 'cosmic rays', 'I want to make an observation', 'observe', 'How to I write an observation?', 'What is your name?', 'Who are you?', 'Friend', 'AI agent', 'Why are you following me?', 'What are your hobbies?', 'What do you like to do?', 'Tell me something about yourself?', 'passions', 'hobby', "Where's the chemist?", 'Chemist', 'Who is the chemist?', 'Where can I find the Chemist?', 'What does the chemist do for their job?', 'Who can I talk to?', 'What npcs are on this map?', 'Where can I find people?', 'Who do I need to speak to?', 'Who am I looking for?', 'Where can I find the exonaut explorer?', 'Exonaut explorer', 'Who is the exonaut explorer?', "Where's the exonaut explorer?", 'What does the exoplanet explorer do for their job?', 'Where can I find the xenobotanist?', 'xenobotanist', 'Who is the xenobotanist?', "Where's the xenobotanist?", 'What does the xenobotanist do for their job?', 'Where can I find the astrozooligist?', 'astrozooligist', 'Who is the astrozooligist?', "Where's the astrozooligist?", 'What does the astrozooligist do for their job?', 'Where can I find the robot?', 'robot', "Where's the robot?", 'What does the robot do?', 'Where can I find Eric Mattson?', 'Eric Mattson', 'Who is Eric Mattson?', "Where's Eric Mattson?", ...
# ['altitude', 'altitude', 'altitude', 'altitude', 'altitude', 'oxygen', 'oxygen', 'oxygen', 'oxygen', 'oxygen', 'airflow', 'airflow', 'airflow', 'airflow', 'airflow', 'atmosphere', 'atmosphere', 'atmosphere', 'atmosphere', 'atmosphere', 'gravity', 'gravity', 'gravity', 'gravity', 'humidity', 'humidity', 'humidity', 'humidity', 'humidity', 'magnetic field', 'magnetic field', 'magnetic field', 'pressure', 'pressure', 'pressure', 'pressure', 'pressure', 'radiation', 'radiation', 'radiation', 'radiation', 'radiation', 'year', 'year', 'year', 'year', 'year', 'planet', 'planet', 'planet', 'planet', 'planet', 'player', 'player', 'player', 'player', 'player', 'caption', 'caption', 'caption', 'caption', 'quest', 'quest', 'quest', 'quest', 'quest', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'tilt', 'tilt', 'tilt', 'tilt', 'tilt', 'tide', 'tide', 'tide', 'tide', 'tide', 'temperature', 'temperature', 'temperature', 'temperature', 'temperature', 'tectonic', 'tectonic', 'tectonic', 'tectonic', 'tectonic', 'day', 'day', 'day', 'day', 'day', 'radius', 'radius', 'radius', 'radius', 'ray', 'ray', 'ray', 'observe', 'observe', 'observe', 'agent', 'agent', 'agent', 'agent', 'agent', 'hobby', 'hobby', 'hobby', 'hobby', 'hobby', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'npcs', 'guidance', 'guidance', 'guidance']

# %%
for i in range(len(X)):
    X[i] = X[i].replace("[^a-zA-Z0-9\\s]", '')
    X[i] = X[i].lower()
X
# Out:
# ['what is my altitude?',
#  'how high up am i?',
#  'altitude here',
#  'height',
#  'alt',
#  'what is the oxygen content?',
#  'can i breath here?',
#  'oxygen',
#  'is there air on this planet?',
#  'air',
#  'how fast is the wind?',
#  'what is the airflow like?',
#  'what is the speed of the air on this planet?',
#  'wind',
#  'airflow',
#  'what is the atmosphere like?',
#  'atmosphere contents',
#  'what is in the water?',
#  'atmosphere',
#  'what is in the air here?',
#  'what is the gravity on this planet?',
#  'gravity',
#  'what is the force pulling me down?',
#  'how fast fo i fall on this planet?',
#  'humidity',
#  'what is the humidity here?',
#  'how moist is the air on this planet?',
#  'what is the water content in the air?',
#  'how humid is it here?',
#  'magnetic field',
#  'what is the magnetic force on this planet?',
#  'what is the force that keeps the planet together?',
#  'pressure',
#  'what is the pressure on the planet?',
#  'what is the force exerted on my body here?',
#  'how much is being pushed on me on this planet?',
#  'would i get crushed here?',
#  'radiation',
#  'what is the amount of radiation on this planet?',
#  'how much energy do i get on this planet?',
#  'can i get sick here?',
#  'wave energy',
#  'what is the year length here?',
#  'how long is a year on this planet?',
#  'how old would i be on this planet?',
#  'year length',
#  'how long does it take for this planet to orbit their sun?',
#  'where am i?',
#  'what planet am i on?',
#  "what's the name of my location?",
#  ' planet name',
#  'location',
#  'who am i?',
#  'what is my name?',
#  'do you know me?',
#  'player',
#  'name',
#  'what is this?',
#  'what am i looking at?',
#  'tell me something about this.',
#  'do you know about this?',
#  'what should i do next?',
#  'where do i go now?',
#  'i am lost.',
#  'quest progress.',
#  "what's next.",
#  'what does saige do for her job?',
#  'where can i find saige?',
#  'who is saige?',
#  'engineer saige',
#  "where's saige?",
#  'how are you?',
#  'hello',
#  "what's up?",
#  'hi',
#  'hey',
#  'see you',
#  'bye',
#  'goodbye',
#  'i got to go',
#  'nice talking to you',
#  'what is the tilt on this planet?',
#  'tilt',
#  'how far off are we from the axis?',
#  'axial tilt',
#  'axis',
#  "what's the tide levels?",
#  'high how are the ocean levels here?',
#  'what are the tides like on this planet?',
#  'ocean level',
#  'tide',
#  "what's the temp on this planet?",
#  'temperature here',
#  'celcius',
#  'kelvin',
#  'fahrenheit',
#  'tektounic',
#  'seismic activity on this planet',
#  'what is the tectonic plates like here?',
#  'tectonic',
#  'what is the seismic activity like here?',
#  'day',
#  'how long does it take for the planet to rotate?',
#  'what is the length of days on this planet?',
#  'what are days like here?',
#  'rotation',
#  'radius',
#  'what is the mean radius of the planet?',
#  'how big is this planet?',
#  'how many miles is the radius here?',
#  'what are the rays like here?',
#  'how much localized cosmic rays are there here?',
#  'cosmic rays',
#  'i want to make an observation',
#  'observe',
#  'how to i write an observation?',
#  'what is your name?',
#  'who are you?',
#  'friend',
#  'ai agent',
#  'why are you following me?',
#  'what are your hobbies?',
#  'what do you like to do?',
#  'tell me something about yourself?',
#  'passions',
#  'hobby',
#  "where's the chemist?",
#  'chemist',
#  'who is the chemist?',
#  'where can i find the chemist?',
#  'what does the chemist do for their job?',
#  'who can i talk to?',
#  'what npcs are on this map?',
#  'where can i find people?',
#  'who do i need to speak to?',
#  'who am i looking for?',
#  'where can i find the exonaut explorer?',
#  'exonaut explorer',
#  'who is the exonaut explorer?',
#  "where's the exonaut explorer?",
#  'what does the exoplanet explorer do for their job?',
#  'where can i find the xenobotanist?',
#  'xenobotanist',
#  'who is the xenobotanist?',
#  "where's the xenobotanist?",
#  'what does the xenobotanist do for their job?',
#  'where can i find the astrozooligist?',
#  'astrozooligist',
#  'who is the astrozooligist?',
#  "where's the astrozooligist?",
#  'what does the astrozooligist do for their job?',
#  'where can i find the robot?',
#  'robot',
#  "where's the robot?",
#  'what does the robot do?',
#  'where can i find eric mattson?',
#  'eric mattson',
#  'who is eric mattson?',
#  "where's eric mattson?",
#  'what does eric mattson do for their job?',
#  'where can i find the prospector?',
#  'prospector',
#  'who is the prospector?',
#  "where's the prospector?",
#  'what does the prospector do for their job?',
#  'where can i find the surveyor?',
#  'surveyor',
#  'who is the surveyor?',
#  "where's the surveyor?",
#  'what does the surveyor do for their job?',
#  'what does kobey do for their job?',
#  'where can i find kobey?',
#  'who is kobey?',
#  'scientist kobey',
#  "where's kobey?",
#  'what does nate do for their job?',
#  'where can i find nate?',
#  'who is nate?',
#  'researcher nate',
#  "where's nate?",
#  'what does galvin do for their job?',
#  'where can i find galvin?',
#  'who is galvin?',
#  'geologist galvin',
#  "where's galvin?",
#  'what does theron do for their job?',
#  'where can i find theron?',
#  'who is theron?',
#  'astronomer theron carmichael',
#  "where's theron?",
#  'can you direct me to {nate}?',
#  'how to i get back to the {start}?',
#  'can i get directions to {pool1}?']

# %%
le = preprocessing.LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([ 2,  2,  2,  2,  2, 15, 15, 15, 15, 15,  1,  1,  1,  1,  1,  3,  3,
#         3,  3,  3,  7,  7,  7,  7, 11, 11, 11, 11, 11, 12, 12, 12, 18, 18,
#        18, 18, 18, 20, 20, 20, 20, 20, 27, 27, 27, 27, 27, 16, 16, 16, 16,
#        16, 17, 17, 17, 17, 17,  4,  4,  4,  4, 19, 19, 19, 19, 19, 13, 13,
#        13, 13, 13,  8,  8,  8,  8,  8,  6,  6,  6,  6,  6, 26, 26, 26, 26,
#        26, 25, 25, 25, 25, 25, 24, 24, 24, 24, 24, 23, 23, 23, 23, 23,  5,
#         5,  5,  5,  5, 21, 21, 21, 21, 22, 22, 22, 14, 14, 14,  0,  0,  0,
#         0,  0, 10, 10, 10, 10, 10, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13,
#        13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13,
#        13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13,
#        13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13,
#        13, 13, 13,  9,  9,  9])

# %%
#Lemma tokenizer error must be Splitter
vectorizer = TfidfVectorizer(analyzer = "word", token_pattern = None, tokenizer = Splitter(), norm = None)
X_vect = vectorizer.fit_transform(X)

# %%
model = neural_network.MLPClassifier()
model = model.fit(X_vect, y)
# Out:
# /Users/samhum/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,

# %%
pipeline = PMMLPipeline([ ('vectorizer',vectorizer),
        ('mlp', model) ])

# %%
le.inverse_transform(pipeline.predict(["Hi"]))
# Out:
# array(['greeting'], dtype='<U14')

# %%
pipeline.predict_proba(["Hi?"])
# Out:
# array([[1.69488319e-03, 1.39120338e-03, 1.17879648e-03, 4.07163320e-04,
#         3.93186662e-04, 6.85599604e-04, 3.42679978e-04, 2.99486629e-04,
#         9.67835226e-01, 1.02720418e-03, 7.42153099e-04, 1.53426307e-03,
#         7.81834502e-04, 5.97088400e-03, 1.29867239e-03, 5.31736910e-04,
#         2.68074878e-03, 1.43781724e-03, 7.41796006e-04, 1.59380916e-03,
#         3.47535423e-03, 4.06482665e-04, 5.31590389e-04, 2.91528939e-04,
#         5.28853333e-04, 7.79213528e-04, 8.96920557e-04, 5.20911788e-04]])

# %%
le.classes_
# Out:
# array(['agent', 'airflow', 'altitude', 'atmosphere', 'caption', 'day',
#        'goodbye', 'gravity', 'greeting', 'guidance', 'hobby', 'humidity',
#        'magnetic field', 'npcs', 'observe', 'oxygen', 'planet', 'player',
#        'pressure', 'quest', 'radiation', 'radius', 'ray', 'tectonic',
#        'temperature', 'tide', 'tilt', 'year'], dtype='<U14')

# %%
len(le.classes_)
# Out:
# 28

# %%
sklearn2pmml(pipeline, 'model.pmml', with_repr = True)
